# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernando-Laboissiere-Oliveira/Atividade-1---Lista-Exerc-cios-Python/blob/main/C%C3%B3pia_de_Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1) Elabore um código que imprima a mensagem *"Olá terráqueos!!"* na tela.
print("Olá terráqueos")
# Out:
# Olá terráqueos

# %%
#2)Elabore um código que peça um número e então mostre a mensagem: "O número informado foi [número]."
Número = int(input("Digite um número: "))
print(f"o número informado foi {Número}")
# Out:
# Digite um número: 67
# o número informado foi 67

# %%
#3)Elabore um código que peça dois números e imprima a soma.
Número1 = int(input("Digite um número: "))
Número2 = int(input("Digite outro número: "))
soma = Número1 + Número2
print(f"A soma é {soma}")
# Out:
# Digite um número: 18
# Digite outro número: 26
# A soma é 44

# %%
#4)Elabore um código que peça as 4 notas bimestrais e mostre a média.
Primeiro_Bimestre = float(input("Digite a nota do primeiro bimestre: "))
Segundo_bimestre = float(input("Digite a nota do segundo bimestre: "))
Terceiro_bimestre = float(input("Digite a nota do terceiro bimestre: "))
Quarto_bimestre = float(input("Digite a nota do quarto bimestre: "))
Média = (Primeiro_Bimestre + Segundo_bimestre + Terceiro_bimestre + Quarto_bimestre) / 4
print(f"A média é {Média}")
# Out:
# Digite a nota do primeiro bimestre: 6
# Digite a nota do segundo bimestre: 9
# Digite a nota do terceiro bimestre: 7
# Digite a nota do quarto bimestre: 5
# A média é 6.75

# %%
#8)Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.
valor_hora = float(input("Quanto você ganha por hora? "))
horas_mes = float(input("Quantas horas você trabalhou no mês? "))
salario_total = valor_hora * horas_mes
print(f"Seu salário total neste mês é de R${salario_total:.2f}.")
# Out:
# Quanto você ganha por hora? 100
# Quantas horas você trabalhou no mês? 300
# Seu salário total neste mês é de R$30000.00.

# %%
#9)Elabore um código que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius. ** Onde C = 5 * ((F-32) / 9)**.
fahrenheit = float(input("Digite a temperatura em graus Fahrenheit: "))
celsius = 5 * ((fahrenheit - 32) / 9)
print(f"A temperatura em graus Celsius é {celsius}")
# Out:
# Digite a temperatura em graus Fahrenheit: 95
# A temperatura em graus Celsius é 35.0

# %%
#6)Elabore um código que peça o raio de um círculo, calcule e mostre sua área.
circulo = float(input("Digite o raio do círculo: "))
area = 3.14 * circulo ** 2
print(f"A área do círculo é {area}")
# Out:
# Digite o raio do círculo: 35
# A área do círculo é 3846.5

# %%
#7)Elabore um código que calcule a área de um quadrado, em seguida mostre o dobro desta área para o usuário.
quadrado = float(input("Digite o lado do quadrado: "))
area = quadrado ** 2
dobro_area = area * 2
print(f"O dobro da área do quadrado é {dobro_area}")
# Out:
# Digite o lado do quadrado: 60
# O dobro da área do quadrado é 7200.0

# %%
#8)Elabore um código que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês em uma mensagem amigável.

# %%
#10)Elabore um código que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
celsius = float(input("Digite a temperatura em graus Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print(f"A temperatura em graus Fahrenheit é {fahrenheit}")
# Out:
# Digite a temperatura em graus Celsius: 36
# A temperatura em graus Fahrenheit é 96.8

# %%
#11)Elabore um código que peça 2 números inteiros e um número real. Calcule e mostre:o produto do dobro do primeiro com metade do segundo .a soma do triplo do primeiro com o terceiro.o terceiro elevado ao cubo.
numero

# %%
#12)Elabore um código que receba os dados de entrada a altura de uma pessoa, e informe qual seria o peso ideal, usando a seguinte fórmula: (72.7*altura) - 58
altura = float(input("Digite a sua altura em metros (ex: 1.75): "))
peso_ideal = (72.7 * altura) - 58
print(f"Seu peso ideal seria: {peso_ideal:.2f} kg")
# Out:
# Digite a sua altura em metros (ex: 1.75): 1.71
# Seu peso ideal seria: 66.32 kg
